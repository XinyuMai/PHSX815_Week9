# %%
import numpy as np
from matplotlib import pyplot as plt
from scipy import optimize
from scipy.optimize import minimize
from numpy.random import rand

def func(parms):
    x,y = parms
    f = (x-2)**2 +y**2 
    return f

 
# define range for input
r_min, r_max = -6.0, 6.0
# define the starting point as a random sample from the domain
pt = r_min + rand(2) * (r_max - r_min)

# sample input range uniformly at 0.1 increments
xaxis = np.arange(r_min, r_max, 0.1)
yaxis = np.arange(r_min, r_max, 0.1)

# create a mesh from the axis
x, y = np.meshgrid(xaxis, yaxis)
# compute targets
results = func([x, y])


# plot the function 
plt.figure(figsize=(10,10))
ax = plt.axes(projection='3d')
ax.contour3D(x, y, results, 500, rstride=1, cstride=1, cmap='viridis', edgecolor='none')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
ax.set_title('My function; $ f(x,y) = (x-2)^2 + y^2 $')
plt.grid()
plt.legend()
plt.show()

# define range for input
r_min, r_max = -6.0, 6.0
# define the starting point as a random sample from the domain
pt = r_min + rand(2) * (r_max - r_min)

# perform the search
result = minimize(func, pt, method='nelder-mead')
# summarize the result
print('Status : %s' % result['message'])
print('Total Evaluations: %d' % result['nfev'])
# evaluate solution
solution = result['x']
evaluation = func(solution)
print('Solution: f(%s) = %.5f' % (solution, evaluation))
# Out:
# <ipython-input-31-161b23f3b64c>:31: UserWarning: The following kwargs were not used by contour: 'rstride', 'cstride', 'edgecolor'
#   ax.contour3D(x, y, results, 500, rstride=1, cstride=1, cmap='viridis', edgecolor='none')
# No handles with labels found to put in legend.
# Status : Optimization terminated successfully.
# Total Evaluations: 72
# Solution: f([1.99995508e+00 2.22623960e-05]) = 0.00000
